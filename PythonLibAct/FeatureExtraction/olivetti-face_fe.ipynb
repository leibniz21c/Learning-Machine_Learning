# %%
#
#
#       2020.11.23 
#       Heesung Yang
#       Olivetti-face Data Set Feature Extraction
#       Env : lisa master(single node)
#
#

# %%
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt
import numpy as np

n_row, n_col = 2, 5
n_components = n_row * n_col
image_shape = (64, 64)

# %%
# Data loading
dataset = fetch_olivetti_faces(shuffle=True)
faces = dataset.data

n_samples, n_features = faces.shape
print(faces.shape) # 400 numbers of people, and each images have 4096 dim.
# Out:
# (400, 4096)

# %%
for i, comp in enumerate(faces[:n_components]):
    plt.subplot(n_row, n_col, i + 1)
    plt.imshow(comp.reshape(image_shape), cmap=plt.cm.gray)
    plt.xticks(())
    plt.yticks(())

# %%
# PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=n_components)
z_pca = pca.fit_transform(faces)

for i, comp in enumerate(pca.components_):
    plt.subplot(n_row, n_col, i + 1)
    plt.imshow(comp.reshape(image_shape), cmap=plt.cm.gray)
    plt.xticks(())
    plt.yticks(())
plt.show()

# %%
# NMF
from sklearn.decomposition import NMF

nmf = NMF(n_components=n_components)
z_nmf = nmf.fit_transform(faces)

for i, comp in enumerate(nmf.components_):
    plt.subplot(n_row, n_col, i + 1)
    plt.imshow(comp.reshape(image_shape), cmap=plt.cm.gray)
    plt.xticks(())
    plt.yticks(())
plt.show()
